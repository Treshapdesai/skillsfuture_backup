# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd
import sklearn

# %%
health = pd.read_csv('health_exp.csv')

# %%
health.plot()
# Out:
# <AxesSubplot:>
